# %%
import yfinance as yf
import pandas as pd

# 40 Verified Tickers (Fixed Yinson and swapped MAHB for Capital A)
tickers = [
    "1155.KL", "1023.KL", "1295.KL", "5819.KL", "7100.KL", "7293.KL", "5202.KL",
    "5347.KL", "6033.KL", "5264.KL", "4707.KL", "3182.KL", "2658.KL", "5183.KL",
    "8869.KL", "5916.KL", "5225.KL", "7113.KL", "5878.KL", "0166.KL", "0097.KL",
    "0138.KL", "5285.KL", "1961.KL", "2445.KL", "5249.KL", "5288.KL", "5401.KL",
    "5398.KL", "3336.KL", "5263.KL", "6947.KL", "6012.KL", "4863.KL", "3816.KL",
    "5099.KL", "5246.KL"
]

# Download data
# We use auto_adjust=True to handle splits/dividends automatically
data = yf.download(tickers, start="2021-01-01", end="2026-01-12", auto_adjust=True)['Close']

# Save as CSV
data.to_csv("bursa_full_universe.csv")

print("Download successful! Saved to data/raw/bursa_full_universe.csv")
# Out:
# [*********************100%***********************]  37 of 37 completed
# Download successful! Saved to data/raw/bursa_full_universe.csv
